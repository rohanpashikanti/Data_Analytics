# %% [markdown]
# <a href="https://colab.research.google.com/github/rohanpashikanti/Data_Analytics/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # libraries Required

# %%
import pandas as pd #--> which is used to import dataset.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ab = pd.read_csv('Automobile.csv')
# ab = pd.read_csv('CAvideos.csv',header= None) --> Used to importing csv without header.

# %% [markdown]
# # Printing the dataframe in Python
# df prints the entire dataframe (not recommended for large datasets)
#
# df.head(n) to show the first n rows of data frame.
#
# df.tail(n) shows the bottom n rows of data frame

# %%
ab.tail()
# Out:
#                 name   mpg  cylinders  displacement  horsepower  weight  \
# 393  ford mustang gl  27.0          4         140.0        86.0    2790
# 394        vw pickup  44.0          4          97.0        52.0    2130
# 395    dodge rampage  32.0          4         135.0        84.0    2295
# 396      ford ranger  28.0          4         120.0        79.0    2625
# 397       chevy s-10  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin
# 393          15.6          82     usa
# 394          24.6          82  europe
# 395          11.6          82     usa
# 396          18.6          82     usa
# 397          19.4          82     usa

# %%
ab.head(2)
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa

# %%
ab.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %% [markdown]
# # Basic insights from the data

# %% [markdown]
# ## Checking Data types

# %%
ab.dtypes
# Out:
# name             object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %% [markdown]
# ## Describing Data
# for statistical data

# %%
ab.describe(include='all')
# Out:
#               name         mpg   cylinders  displacement  horsepower  \
# count          398  398.000000  398.000000    398.000000  392.000000
# unique         305         NaN         NaN           NaN         NaN
# top     ford pinto         NaN         NaN           NaN         NaN
# freq             6         NaN         NaN           NaN         NaN
# mean           NaN   23.514573    5.454774    193.425879  104.469388
# std            NaN    7.815984    1.701004    104.269838   38.491160
# min            NaN    9.000000    3.000000     68.000000   46.000000
# 25%            NaN   17.500000    4.000000    104.250000   75.000000
# 50%            NaN   23.000000    4.000000    148.500000   93.500000
# 75%            NaN   29.000000    8.000000    262.000000  126.000000
# max            NaN   46.600000    8.000000    455.000000  230.000000
#
#              weight  acceleration  model_year origin
# count    398.000000    398.000000  398.000000    398
# ...

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# # Data pre-processing
# The process of converting or mapping data from the initial "raw" form into another format, in order to prepare the data for further analysis.

# %% [markdown]
# ## Dealing with Missing Values in Python

# %% [markdown]
# ### drop missing values
# axis=0 drops the entire row
#
# axis=1 drops the entire column

# %%
ab.count()
# Out:
# name            398
# mpg             398
# cylinders       398
# displacement    398
# horsepower      392
# weight          398
# acceleration    398
# model_year      398
# origin          398
# dtype: int64

# %%
# ab.dropna(subset=['horsepower'],axis=0,inplace=True)

# %% [markdown]
# ### Replace missing data with frequency

# %%
#MostFrequentEntry = df['attribute_name'].value_counts().idxmax()
#df['attribute_name'].replace(np.nan,MostFrequentEntry
#df['attribute_name'].replace(np.nan,MostFrequentEntry, inplace=True)

# %% [markdown]
# ### Replace missing data with mean

# %%
AverageValue=ab['horsepower'].mean(axis=0)
ab['horsepower'].replace(np.nan, AverageValue, inplace=True)

# %%
ab.count()
# Out:
# name            398
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model_year      398
# origin          398
# dtype: int64

# %% [markdown]
# # Data Formatting

# %% [markdown]
# ## Correcting Datatypes

# %%
ab.dtypes
# Out:
# name             object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
ab['weight'] = ab['weight'].astype('float')
ab.dtypes['weight']
# Out:
# dtype('float64')

# %% [markdown]
# # Data Normalization
# *   Uniform the features value with different range.

# %%
ab.describe()
# Out:
#               mpg   cylinders  displacement  horsepower  acceleration  \
# count  398.000000  398.000000    398.000000  398.000000    398.000000
# mean    23.514573    5.454774    193.425879    0.454215     15.568090
# std      7.815984    1.701004    104.269838    0.166083      2.757689
# min      9.000000    3.000000     68.000000    0.200000      8.000000
# 25%     17.500000    4.000000    104.250000    0.330435     13.825000
# 50%     23.000000    4.000000    148.500000    0.413043     15.500000
# 75%     29.000000    8.000000    262.000000    0.543478     17.175000
# max     46.600000    8.000000    455.000000    1.000000     24.800000
#
#        model_year
# count  398.000000
# mean    76.010050
# std      3.697627
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %% [markdown]
# ## Simple Feature Scaling

# %%
ab ["horsepower"] = ab["horsepower"]/ab["horsepower"].max ()

# %% [markdown]
# ## Min - Max

# %%
# ab ["horsepower"] = (ab ["horsepower"]-ab ["horsepower"] min () ) /(ab ["horsepower"]. max () -ab ["horsepower"] min () )

# %% [markdown]
# ## Z-Score

# %%
#ab["horsepower"] = (ab["horsepower"]-ab ["horsepower"] mean ()) /ab["horsepower"].std ()

# %%
ab.describe()
# Out:
#               mpg   cylinders  displacement  horsepower  acceleration  \
# count  398.000000  398.000000    398.000000  398.000000    398.000000
# mean    23.514573    5.454774    193.425879    0.454215     15.568090
# std      7.815984    1.701004    104.269838    0.166083      2.757689
# min      9.000000    3.000000     68.000000    0.200000      8.000000
# 25%     17.500000    4.000000    104.250000    0.330435     13.825000
# 50%     23.000000    4.000000    148.500000    0.413043     15.500000
# 75%     29.000000    8.000000    262.000000    0.543478     17.175000
# max     46.600000    8.000000    455.000000    1.000000     24.800000
#
#        model_year
# count  398.000000
# mean    76.010050
# std      3.697627
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %% [markdown]
# # Binning
# * Binning: Grouping of values into bins"
# * Converts numeric into categorical variables
# * Group a set of numerical values into a set of "bins"
# * "price" is an feature range from 5,000 to 45,500

# %%
ab.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879    0.454215  2970.424623
# std      7.815984    1.701004    104.269838    0.166083   846.841774
# min      9.000000    3.000000     68.000000    0.200000  1613.000000
# 25%     17.500000    4.000000    104.250000    0.330435  2223.750000
# 50%     23.000000    4.000000    148.500000    0.413043  2803.500000
# 75%     29.000000    8.000000    262.000000    0.543478  3608.000000
# max     46.600000    8.000000    455.000000    1.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
bins = np.linspace(min(ab['weight']),max(ab['weight']),4)
GroupNames = ['Low','Medium','High'] #Added a label to match the number of bins
ab['weight'] = pd.cut(ab['weight'], bins, labels=GroupNames, include_lowest=True)

# %%
import matplotlib.pyplot as plt
plt.hist(ab["weight"])
# Out:
# (array([138.,   0.,   0.,   0.,   0.,  65.,   0.,   0.,   0., 195.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Turn Categorical Variables Into Quantitative Variables

# %% [markdown]
# ## Dummy variables in Python pandas
# * Use pandas.get _dummies method.
# * Convert categorical variables to dummy variables (0 or 1)

# %%
ab.head(2)
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0    0.565217
# 1          buick skylark 320  15.0          8         350.0    0.717391
#
#    weight  acceleration  model_year origin
# 0  Medium          12.0          70    usa
# 1  Medium          11.5          70    usa

# %%
pd.get_dummies(ab['origin'])
# Out:
#      europe  japan    usa
# 0     False  False   True
# 1     False  False   True
# 2     False  False   True
# 3     False  False   True
# 4     False  False   True
# ..      ...    ...    ...
# 393   False  False   True
# 394    True  False  False
# 395   False  False   True
# 396   False  False   True
# 397   False  False   True
#
# [398 rows x 3 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
#
# 1. Summarize main characteristics of the data.
# 2.   Gain better understanding of the data set.
# 3. Uncover relationships between variables.
# 4. Extract important variables

# %% [markdown]
# ## Learning Objectives
# 1. escriptive Statistics
# 2. GroupBy
# 3. ANOVA
# 4. Correlation
# 5. Correlation - Statistics

# %% [markdown]
# ## Descriptive Statistics: Value_Counts

# %%
carcylinder = ab['cylinders'].value_counts()
carcylinder
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %% [markdown]
# ## Descriptive Statistics: Box Plots

# %%
sns.boxplot(x="cylinders", y="weight", data=ab)
# Out:
# <Axes: xlabel='cylinders', ylabel='weight'>

# %% [markdown]
# ## Descriptive Statistics: Scatter Plot
# * Each observation represented as a point
# * Scatter plots show the relationship between two variables:
# 1. Predictor/independent variables on x-axis
# 2. Target/dependent variables on y-axis

# %%
y=ab["horsepower"]
x=ab["weight"]
plt.scatter(x,y)
plt.xlabel("Weight")
plt.ylabel("Horsepower")
plt.title('Scatter Plot of Horsepower vs weight')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Horsepower vs weight')

# %% [markdown]
# ## GroupBy

# %%
ab_grp = ab.groupby(['name','origin'],as_index=True).mean()
ab_grp
# Out:
#                                   mpg  cylinders  displacement  horsepower  \
# name                    origin
# amc ambassador brougham usa     13.00        8.0         360.0       175.0
# amc ambassador dpl      usa     15.00        8.0         390.0       190.0
# amc ambassador sst      usa     17.00        8.0         304.0       150.0
# amc concord             usa     21.85        5.0         191.5        90.0
# amc concord d/l         usa     18.10        6.0         258.0       120.0
# ...                               ...        ...           ...         ...
# vw dasher (diesel)      europe  43.40        4.0          90.0        48.0
# vw pickup               europe  44.00        4.0          97.0        52.0
# vw rabbit               europe  35.25        4.0          94.0        73.0
# vw rabbit c (diesel)    europe  44.30        4.0          90.0        48.0
# vw rabbit custom        europe  31.90        4.0          89.0        71.0
#
# ...

# %% [markdown]
# ## Pandas method: Pivot
# * One variable is displayed along the columns, and the other variable is displayed along the rows

# %%
# Convert the index to columns
ab_grp = ab_grp.reset_index()
ab_grp
ab_pivot = ab_grp.pivot(index='name', columns='origin')
ab_pivot
# Out:
#                         level_0             index               mpg        \
# origin                   europe japan  usa europe japan  usa europe japan
# name
# amc ambassador brougham     NaN   NaN  0.0    NaN   NaN  0.0    NaN   NaN
# amc ambassador dpl          NaN   NaN  1.0    NaN   NaN  1.0    NaN   NaN
# amc ambassador sst          NaN   NaN  2.0    NaN   NaN  2.0    NaN   NaN
# amc concord                 NaN   NaN  3.0    NaN   NaN  3.0    NaN   NaN
# amc concord d/l             NaN   NaN  4.0    NaN   NaN  4.0    NaN   NaN
# ...                         ...   ...  ...    ...   ...  ...    ...   ...
# vw dasher (diesel)        300.0   NaN  NaN  300.0   NaN  NaN  43.40   NaN
# vw pickup                 301.0   NaN  NaN  301.0   NaN  NaN  44.00   NaN
# vw rabbit                 302.0   NaN  NaN  302.0   NaN  NaN  35.25   NaN
# vw rabbit c (diesel)      303.0   NaN  NaN  303.0   NaN  NaN  44.30   NaN
# vw rabbit custom          304.0   NaN  NaN  304.0   NaN  NaN  31.90   NaN
#
# ...

# %% [markdown]
# ## Heatmap
# * Plot target variable against multiple variables

# %%
plt.pcolor(ab_pivot, cmap='RdBu')
plt.colorbar()
plt. show()

# %% [markdown]
# ## Data Visualization commands

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### matplotlib functions
# ### 1. Standard Line Plot

# %%
plt.plot(x,y)

# %% [markdown]
# ### 2. Scatter plot

# %%
plt.scatter(x,y)

# %% [markdown]
# ### 3. Histogram

# %%
plt.hist(x,bins)
# Out:
# (array([195., 138.,  65.]),
#  array([1613.        , 2788.66666667, 3964.33333333, 5140.        ]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# ### 4. Bar plot

# %%
plt.bar(x,20,5)
# Out:
# <BarContainer object of 398 artists>

# %% [markdown]
# ### 5. Pseudo Color Plot

# %%
C = ab_pivot
plt.pcolor(C)
plt.colorbar()
plt.show()

# %% [markdown]
# ### seaborn functions
# ### 1. Regression plot

# %%
sns.regplot(x="weight", y="horsepower", data=ab)
# Out:
# <Axes: xlabel='weight', ylabel='horsepower'>

# %% [markdown]
# ### 2. Box and whisker plot

# %%
sns.boxplot(x="cylinders", y="weight", data=ab)
# Out:
# <Axes: xlabel='cylinders', ylabel='weight'>

# %% [markdown]
# ### 3. Residual Plot

# %%
sns.residplot(x=ab['horsepower'], y=ab['weight'])
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %% [markdown]
# ### 4. KDE plot

# %%
sns.kdeplot(ab['horsepower'])
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# ### 5. Distribution Plot

# %%
sns.distplot(ab['horsepower'])
# Out:
# <ipython-input-92-b32ab82255f4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ab['horsepower'])
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
sns.distplot(x,hist=False)
# Out:
# <ipython-input-94-e76091fef7d8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,hist=False)
# <Axes: xlabel='weight', ylabel='Density'>

# %% [markdown]
# ## Correlation
# * measuring to what extent different variables are interdependent.

# %%
# Correlation: Positive linear relationship for my dataset

sns.regplot(x="weight", y="horsepower", data=ab)
plt.ylim(0,)
# Out:
# (0.0, 239.2)

# %%
# Correlation: Negative linear relationship

sns.regplot(x="horsepower",y="cylinders", data=ab)
plt.ylim(0,)
# Out:
# (0.0, 10.947082130044844)

# %% [markdown]
# ## Correlation - Statistics
# * Measure the strength of the correlation between two features
# 1. Correlation coefficient
# 2. P-value
#
# * Correlation coefficient
# 1. Close to +1: Large Positive relationship
# 2. Close to -1: Large Negative relationship
# 3. Close to 0: No relationship
#
# * P-value
# 1. P-value < 0.001 Strong certainty in the result
# 2. P-value < 0.05 Moderate certainty in the result
# 3. P-value < 0.1 Weak certainty in the result
# 4. P-value > 0. 1 No certainty in the result
#
# * Strong correlation
# 1. Correlation coefficient close to 1 or -1
# 2. P value less than 0.001

# %%
#from scipy import stats
#pearson_coef, p_value = stats.pearsonr(ab['horsepower'], ab['cylinders'])
#print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)

#pearson_coef, p_value = stats.pearsonr(ab['horsepower'], ab['weight'])
#print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)

# %% [markdown]
# ## Co-relation Heatmap

# %%
ab[['horsepower','cylinders']].corr()
# Out:
#             horsepower  cylinders
# horsepower    1.000000   0.842983
# cylinders     0.842983   1.000000

# %%
sns.heatmap(ab[['horsepower','cylinders']].corr(), cmap='coolwarm')
plt.show()
